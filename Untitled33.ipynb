# %%
#importing required libraries
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('chandrayaan..jpg',0)

# %%
plt.imshow(img,cmap='gray')

# %%
inv=225-img
plt.imshow(inv,cmap='gray')

# %%
blur=cv2.GaussianBlur(inv,ksize=(21,21),sigmaX=0,sigmaY=0)

# %%
plt.imshow(blur,cmap='gray')

# %%
dodge=lambda image,mark:cv2.divide(image,255-mask,scale=256)

# %%
import cv2
image = cv2.imread("'chandrayaan..jpg'")
mask = cv2.imread("'chandrayaan..jpg'", cv2.IMREAD_GRAYSCALE)

# %%
dodge = lambda image, mask: cv2.divide(image,225-mask, scale=256)

# %%
blen = dodge(img,blur)
plt.imshow(blen,cmap='gray')

# %%
cv2.imwrite('chandrayaan..jpg', blen)
# Out:
# True
